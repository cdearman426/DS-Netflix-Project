# %% [markdown]
# # GDP Data Cleaning

# %% [markdown]
# This notebook cleans the World Bank GDP data to only include GDP values for 2021, region, and IncomeGroup variables. Following cleaning, the data is merged with the Netflix data.
# Only the countries included in both datasets are kept in the final analytic dataset.

# %%
import pandas as pd 
import numpy as np 
import os

# %%
os.chdir("/Users/steffenerickson/Desktop/repos/DS-Netflix-Project")

# %%
path_to_gdp = "/Users/steffenerickson/Desktop/repos/DS-Netflix-Project/gdp_data/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_3628616.csv"

# %%
path_to_metadata = "/Users/steffenerickson/Desktop/repos/DS-Netflix-Project/gdp_data/Metadata_Country_API_NY.GDP.MKTP.CD_DS2_en_csv_v2_3628616.csv"

# %%
path_to_netflix = "/Users/steffenerickson/Desktop/repos/DS-Netflix-Project/Netflix subscription fee Dec-2021.csv"

# %% [markdown]
#  ### Cleaning GDP Data

# %%
df_gdp = pd.read_csv(path_to_gdp, skiprows = 3, header = 0 , dtype = str)

# %%
df_gdp2 = df_gdp[['Country Code','Country Name', '2020']].copy()

# %%
df_gdp2 = df_gdp2.rename(columns={'2020':'2020_GDP'})
df_gdp2['2020_GDP'] = df_gdp2['2020_GDP'].apply(lambda x: float(x) if isinstance(x, str) else x)

# %%
df_gdp2.head()
# Out:
#   Country Code                 Country Name      2020_GDP
# 0          ABW                        Aruba           NaN
# 1          AFE  Africa Eastern and Southern  9.207923e+11
# 2          AFG                  Afghanistan  2.011614e+10
# 3          AFW   Africa Western and Central  7.845876e+11
# 4          AGO                       Angola  5.837598e+10

# %% [markdown]
# ### Cleaning Meta Data

# %%
df_meta = pd.read_csv(path_to_metadata, header = 0 , dtype = str, usecols = [0,1,2])

# %%
df_meta.head()
len(df_meta)
# Out:
# 265

# %% [markdown]
# ### Merging data

# %%
GDP_Final = pd.merge(df_gdp2, df_meta, on="Country Code", how="right")

# %%
GDP_Final.head(30)
# Out:
#    Country Code                 Country Name      2020_GDP  \
# 0           ABW                        Aruba           NaN
# 1           AFE  Africa Eastern and Southern  9.207923e+11
# 2           AFG                  Afghanistan  2.011614e+10
# 3           AFW   Africa Western and Central  7.845876e+11
# 4           AGO                       Angola  5.837598e+10
# 5           ALB                      Albania  1.488763e+10
# 6           AND                      Andorra           NaN
# 7           ARB                   Arab World  2.447584e+12
# 8           ARE         United Arab Emirates  3.588688e+11
# 9           ARG                    Argentina  3.892881e+11
# 10          ARM                      Armenia  1.264121e+10
# 11          ASM               American Samoa  7.090000e+08
# 12          ATG          Antigua and Barbuda  1.370281e+09
# 13          AUS                    Australia  1.327836e+12
# 14          AUT                      Austria  4.332585e+11
# 15          AZE                   Azerbaijan  4.260718e+10
# 16          BDI                      Burundi  2.841786e+09
# 17          BEL                      Belgium  5.218613e+11
# 18          BEN                        Benin  1.565155e+10
# 19          BFA                 Burkina Faso  1.793361e+10
# 20          BGD                   Bangladesh  3.230570e+11
# 21          BGR                     Bulgaria  6.988935e+10
# 22          BHR                      Bahrain  3.472923e+10
# 23          BHS                 Bahamas, The  9.907500e+09
# 24          BIH       Bosnia and Herzegovina  1.994650e+10
# 25          BLR                      Belarus  6.025824e+10
# 26          BLZ                       Belize  1.636281e+09
# 27          BMU                      Bermuda  6.842700e+09
# 28          BOL                      Bolivia  3.657276e+10
# 29          BRA                       Brazil  1.444733e+12
#
#                         Region          IncomeGroup
# 0    Latin America & Caribbean          High income
# 1                          NaN                  NaN
# 2                   South Asia           Low income
# 3                          NaN                  NaN
# 4           Sub-Saharan Africa  Lower middle income
# 5        Europe & Central Asia  Upper middle income
# 6        Europe & Central Asia          High income
# 7                          NaN                  NaN
# 8   Middle East & North Africa          High income
# 9    Latin America & Caribbean  Upper middle income
# 10       Europe & Central Asia  Upper middle income
# 11         East Asia & Pacific  Upper middle income
# 12   Latin America & Caribbean          High income
# 13         East Asia & Pacific          High income
# 14       Europe & Central Asia          High income
# 15       Europe & Central Asia  Upper middle income
# 16          Sub-Saharan Africa           Low income
# 17       Europe & Central Asia          High income
# 18          Sub-Saharan Africa  Lower middle income
# 19          Sub-Saharan Africa           Low income
# 20                  South Asia  Lower middle income
# 21       Europe & Central Asia  Upper middle income
# 22  Middle East & North Africa          High income
# 23   Latin America & Caribbean          High income
# 24       Europe & Central Asia  Upper middle income
# 25       Europe & Central Asia  Upper middle income
# 26   Latin America & Caribbean  Lower middle income
# 27               North America          High income
# 28   Latin America & Caribbean  Lower middle income
# 29   Latin America & Caribbean  Upper middle income

# %% [markdown]
# ### Exporting GDP Data

# %%
GDP_Final.to_csv('gdp_data/gdp_final.csv')

# %% [markdown]
# ### Merging with Netlflix data

# %%
netflix = pd.read_csv(path_to_netflix, header = 0)

# %%
netflix = netflix.rename(columns={'Country':'Country Name'})

# %%
#Change the names for a perfect match 
GDP_Final.replace({'Country Name':{'Czech Republic': 'Czechia', 'Hong Kong SAR, China': 'Hong Kong', 
                 'Russian Federation': 'Russia', 'Slovak Republic': 'Slovakia',
                 'Korea, Rep.': 'South Korea', 'Venezuela, RB': 'Venezuela'}}, value = None, inplace=True)
                            
GDP_Final.tail(50)
# Out:
#     Country Code                                       Country Name  \
# 215          SSD                                        South Sudan
# 216          SSF                                 Sub-Saharan Africa
# 217          SST                                       Small states
# 218          STP                              Sao Tome and Principe
# 219          SUR                                           Suriname
# 220          SVK                                           Slovakia
# 221          SVN                                           Slovenia
# 222          SWE                                             Sweden
# 223          SWZ                                           Eswatini
# 224          SXM                          Sint Maarten (Dutch part)
# 225          SYC                                         Seychelles
# 226          SYR                               Syrian Arab Republic
# 227          TCA                           Turks and Caicos Islands
# 228          TCD                                               Chad
# 229          TEA         East Asia & Pacific (IDA & IBRD countries)
# 230          TEC       Europe & Central Asia (IDA & IBRD countries)
# 231          TGO                                               Togo
# 232          THA                                           Thailand
# 233          TJK                                         Tajikistan
# 234          TKM                                       Turkmenistan
# 235          TLA  Latin America & the Caribbean (IDA & IBRD coun...
# 236          TLS                                        Timor-Leste
# 237          TMN  Middle East & North Africa (IDA & IBRD countries)
# 238          TON                                              Tonga
# 239          TSA                            South Asia (IDA & IBRD)
# 240          TSS          Sub-Saharan Africa (IDA & IBRD countries)
# 241          TTO                                Trinidad and Tobago
# 242          TUN                                            Tunisia
# 243          TUR                                             Turkey
# 244          TUV                                             Tuvalu
# 245          TZA                                           Tanzania
# 246          UGA                                             Uganda
# 247          UKR                                            Ukraine
# 248          UMC                                Upper middle income
# 249          URY                                            Uruguay
# 250          USA                                      United States
# 251          UZB                                         Uzbekistan
# 252          VCT                     St. Vincent and the Grenadines
# 253          VEN                                          Venezuela
# 254          VGB                             British Virgin Islands
# 255          VIR                              Virgin Islands (U.S.)
# 256          VNM                                            Vietnam
# 257          VUT                                            Vanuatu
# 258          WLD                                              World
# 259          WSM                                              Samoa
# 260          XKX                                             Kosovo
# 261          YEM                                        Yemen, Rep.
# 262          ZAF                                       South Africa
# 263          ZMB                                             Zambia
# 264          ZWE                                           Zimbabwe
#
#          2020_GDP                      Region          IncomeGroup
# 215           NaN          Sub-Saharan Africa           Low income
# 216  1.705380e+12                         NaN                  NaN
# 217  4.514237e+11                         NaN                  NaN
# 218  4.729145e+08          Sub-Saharan Africa  Lower middle income
# 219  2.884248e+09   Latin America & Caribbean  Upper middle income
# 220  1.051726e+11       Europe & Central Asia          High income
# 221  5.358961e+10       Europe & Central Asia          High income
# 222  5.412201e+11       Europe & Central Asia          High income
# 223  3.972729e+09          Sub-Saharan Africa  Lower middle income
# 224           NaN   Latin America & Caribbean          High income
# 225  1.059886e+09          Sub-Saharan Africa          High income
# 226           NaN  Middle East & North Africa           Low income
# 227  9.245830e+08   Latin America & Caribbean          High income
# 228  1.082908e+10          Sub-Saharan Africa           Low income
# 229  1.742666e+13                         NaN                  NaN
# 230  3.876733e+12                         NaN                  NaN
# 231  7.574637e+09          Sub-Saharan Africa           Low income
# 232  5.016437e+11         East Asia & Pacific  Upper middle income
# 233  8.194150e+09       Europe & Central Asia  Lower middle income
# 234           NaN       Europe & Central Asia  Upper middle income
# 235  4.478206e+12                         NaN                  NaN
# 236  1.902157e+09         East Asia & Pacific  Lower middle income
# 237  1.180179e+12                         NaN                  NaN
# 238  4.888300e+08         East Asia & Pacific  Upper middle income
# 239  3.386420e+12                         NaN                  NaN
# 240  1.705380e+12                         NaN                  NaN
# 241  2.158804e+10   Latin America & Caribbean          High income
# 242  4.162035e+10  Middle East & North Africa  Lower middle income
# 243  7.199548e+11       Europe & Central Asia  Upper middle income
# 244  4.885555e+07         East Asia & Pacific  Upper middle income
# 245  6.240971e+10          Sub-Saharan Africa  Lower middle income
# 246  3.760037e+10          Sub-Saharan Africa           Low income
# 247  1.554990e+11       Europe & Central Asia  Lower middle income
# 248  2.315067e+13                         NaN                  NaN
# 249  5.362883e+10   Latin America & Caribbean          High income
# 250  2.095303e+13               North America          High income
# 251  5.992995e+10       Europe & Central Asia  Lower middle income
# 252  8.074741e+08   Latin America & Caribbean  Upper middle income
# 253           NaN   Latin America & Caribbean                  NaN
# 254           NaN   Latin America & Caribbean          High income
# 255           NaN   Latin America & Caribbean          High income
# 256  2.711584e+11         East Asia & Pacific  Lower middle income
# 257  8.815479e+08         East Asia & Pacific  Lower middle income
# 258  8.474698e+13                         NaN                  NaN
# 259  8.071008e+08         East Asia & Pacific  Lower middle income
# 260  7.716925e+09       Europe & Central Asia  Upper middle income
# 261           NaN  Middle East & North Africa           Low income
# 262  3.354421e+11          Sub-Saharan Africa  Upper middle income
# 263  1.811063e+10          Sub-Saharan Africa  Lower middle income
# 264  1.805117e+10          Sub-Saharan Africa  Lower middle income

# %%
netflix_gdp = pd.merge(netflix, GDP_Final, on = "Country Name", how = "left")

# %%
netflix_gdp2 = netflix_gdp.drop(columns = 'Country Code')

# %%
netflix_gdp2 = netflix_gdp2.rename(columns={'Country Name':'Country'})

# %%
netflix_gdp2.head(20)
# Out:
#    Country_code     Country  Total Library Size  No. of TV Shows  \
# 0            ar   Argentina                4760             3154
# 1            au   Australia                6114             4050
# 2            at     Austria                5640             3779
# 3            be     Belgium                4990             3374
# 4            bo     Bolivia                4991             3155
# 5            br      Brazil                4972             3162
# 6            bg    Bulgaria                6797             4819
# 7            ca      Canada                6239             4311
# 8            cl       Chile                4994             3156
# 9            co    Colombia                4991             3156
# 10           cr  Costa Rica                4988             3152
# 11           hr     Croatia                2274             1675
# 12           cz     Czechia                7325             5234
# 13           dk     Denmark                4558             2978
# 14           ec     Ecuador                4992             3155
# 15           ee     Estonia                6456             4486
# 16           fi     Finland                4045             2638
# 17           fr      France                5445             3604
# 18           de     Germany                5668             3814
# 19           gi   Gibraltar                6167             4079
#
#     No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0            1606                        3.74                           6.30
# 1            2064                        7.84                          12.12
# 2            1861                        9.03                          14.67
# 3            1616                       10.16                          15.24
# 4            1836                        7.99                          10.99
# 5            1810                        4.61                           7.11
# 6            1978                        9.03                          11.29
# 7            1928                        7.91                          11.87
# 8            1838                        7.07                           9.91
# 9            1835                        4.31                           6.86
# 10           1836                        8.99                          12.99
# 11            599                        9.03                          11.29
# 12           2091                        8.83                          11.49
# 13           1580                       12.00                          15.04
# 14           1837                        7.99                          10.99
# 15           1970                        9.03                          11.29
# 16           1407                        9.03                          13.54
# 17           1841                       10.16                          15.24
# 18           1854                        9.03                          14.67
# 19           2088                        9.03                          14.67
#
#     Cost Per Month - Premium ($)      2020_GDP                     Region  \
# 0                           9.26  3.892881e+11  Latin America & Caribbean
# 1                          16.39  1.327836e+12        East Asia & Pacific
# 2                          20.32  4.332585e+11      Europe & Central Asia
# 3                          20.32  5.218613e+11      Europe & Central Asia
# 4                          13.99  3.657276e+10  Latin America & Caribbean
# 5                           9.96  1.444733e+12  Latin America & Caribbean
# 6                          13.54  6.988935e+10      Europe & Central Asia
# 7                          15.03  1.645423e+12              North America
# 8                          12.74  2.529400e+11  Latin America & Caribbean
# 9                           9.93  2.714376e+11  Latin America & Caribbean
# 10                         15.99  6.184690e+10  Latin America & Caribbean
# 11                         13.54  5.720378e+10      Europe & Central Asia
# 12                         14.15  2.453393e+11      Europe & Central Asia
# 13                         19.60  3.560849e+11      Europe & Central Asia
# 14                         13.99  9.880801e+10  Latin America & Caribbean
# 15                         13.54  3.065029e+10      Europe & Central Asia
# 16                         18.06  2.695948e+11      Europe & Central Asia
# 17                         20.32  2.630318e+12      Europe & Central Asia
# 18                         20.32  3.846414e+12      Europe & Central Asia
# 19                         20.32           NaN      Europe & Central Asia
#
#             IncomeGroup
# 0   Upper middle income
# 1           High income
# 2           High income
# 3           High income
# 4   Lower middle income
# 5   Upper middle income
# 6   Upper middle income
# 7           High income
# 8           High income
# 9   Upper middle income
# 10  Upper middle income
# 11          High income
# 12          High income
# 13          High income
# 14  Upper middle income
# 15          High income
# 16          High income
# 17          High income
# 18          High income
# 19          High income

# %% [markdown]
# ### Exporting Final Analystic Dataset

# %%
netflix_gdp2.to_csv('Netflix_GDP_Merged.csv')
